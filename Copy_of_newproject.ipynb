# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritamart/project/blob/main/Copy_of_newproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import statsmodels.api as sm
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/jewelry_with_header (2).csv')

# %%
df.head()
#no columns, add columns
columns = ['order_date','order_id','user_id','purchase','category_id','category','brand','price','price_id','buyer','colour1','colour2','type']
df.columns = columns
print(df.head())
# Out:
#                 order_date             order_id              user_id  \
# 0  2018-12-01 11:40:29 UTC  1924719191579950000  1842195256808830000
# 1  2018-12-01 17:38:31 UTC  1924899396621690000  1806829193678290000
# 2  2018-12-02 13:53:42 UTC  1925511016616030000  1842214461889310000
# 3  2018-12-02 17:44:02 UTC  1925626951238680000  1835566849434050000
# 4  2018-12-02 21:30:19 UTC  1925740842841010000  1873936840742920000
#
#    purchase   category_id          category  brand   price      price_id  \
# 0         1  1.806829e+18   jewelry.earring    0.0  561.51  1.515916e+18
# 1         1  1.806829e+18               NaN    NaN  212.14  1.515916e+18
# 2         1  1.806829e+18   jewelry.pendant    1.0   54.66  1.515916e+18
# 3         1  1.806829e+18   jewelry.pendant    0.0   88.90  1.515916e+18
# 4         1  1.806829e+18  jewelry.necklace    0.0  417.67  1.515916e+18
#
#   buyer colour1 colour2      type
# 0   NaN     red    gold   diamond
# 1   NaN  yellow    gold       NaN
# 2     f   white    gold  sapphire
# 3     f     red    gold   diamond
# 4   NaN     red    gold  amethyst

# %%
import datetime as dt
import matplotlib.pyplot as plt
df['date'] = pd.to_datetime(df['order_date']).dt.date
df['date']
# Out:
# 0        2018-12-01
# 1        2018-12-01
# 2        2018-12-02
# 3        2018-12-02
# 4        2018-12-02
#             ...
# 95906    2021-12-01
# 95907    2021-12-01
# 95908    2021-12-01
# 95909    2021-12-01
# 95910    2021-12-01
# Name: date, Length: 95911, dtype: object

# %%
df['year'] = pd.DatetimeIndex(df['date']).year
df['year'][:5]
# Out:
# 0    2018
# 1    2018
# 2    2018
# 3    2018
# 4    2018
# Name: year, dtype: int64

# %%
df['month'] = pd.DatetimeIndex(df['date']).month
df['month'][:5]
# Out:
# 0    12
# 1    12
# 2    12
# 3    12
# 4    12
# Name: month, dtype: int64

# %%
df
# Out:
#                     order_date             order_id              user_id  \
# 0      2018-12-01 11:40:29 UTC  1924719191579950000  1842195256808830000
# 1      2018-12-01 17:38:31 UTC  1924899396621690000  1806829193678290000
# 2      2018-12-02 13:53:42 UTC  1925511016616030000  1842214461889310000
# 3      2018-12-02 17:44:02 UTC  1925626951238680000  1835566849434050000
# 4      2018-12-02 21:30:19 UTC  1925740842841010000  1873936840742920000
# ...                        ...                  ...                  ...
# 95906  2021-12-01 09:47:37 UTC  2719016587653800000  1515966223597820000
# 95907  2021-12-01 09:50:37 UTC  2719018098886700000  1956663830729720000
# 95908  2021-12-01 09:52:06 UTC  2719018846999540000  1956663848219960000
# 95909  2021-12-01 09:55:35 UTC  2719020596963830000  1835566854106510000
# 95910  2021-12-01 09:59:07 UTC  2719022379232650000  1956663846156370000
#
#        purchase   category_id          category         brand   price  \
# 0             1  1.806829e+18   jewelry.earring  0.000000e+00  561.51
# 1             1  1.806829e+18               NaN           NaN  212.14
# 2             1  1.806829e+18   jewelry.pendant  1.000000e+00   54.66
# 3             1  1.806829e+18   jewelry.pendant  0.000000e+00   88.90
# 4             1  1.806829e+18  jewelry.necklace  0.000000e+00  417.67
# ...         ...           ...               ...           ...     ...
# 95906         1           NaN                 0  1.515920e+18     NaN
# 95907         1  1.806829e+18               NaN  0.000000e+00  229.99
# 95908         1  1.806829e+18   jewelry.earring  1.000000e+00  630.00
# 95909         1  1.806829e+18   jewelry.earring  0.000000e+00   83.42
# 95910         1  1.806829e+18   jewelry.pendant  1.000000e+00   97.12
#
#            price_id buyer colour1 colour2      type        date  year  month
# 0      1.515916e+18   NaN     red    gold   diamond  2018-12-01  2018     12
# 1      1.515916e+18   NaN  yellow    gold       NaN  2018-12-01  2018     12
# 2      1.515916e+18     f   white    gold  sapphire  2018-12-02  2018     12
# 3      1.515916e+18     f     red    gold   diamond  2018-12-02  2018     12
# 4      1.515916e+18   NaN     red    gold  amethyst  2018-12-02  2018     12
# ...             ...   ...     ...     ...       ...         ...   ...    ...
# 95906           NaN   NaN     NaN     NaN       NaN  2021-12-01  2021     12
# 95907  1.515916e+18   NaN     red    gold       NaN  2021-12-01  2021     12
# 95908  1.515916e+18     f   white    gold   diamond  2021-12-01  2021     12
# 95909  1.515916e+18   NaN   white    gold    fianit  2021-12-01  2021     12
# 95910  1.515916e+18   NaN     red    gold       NaN  2021-12-01  2021     12
#
# [95911 rows x 16 columns]

# %%
df['category'] =  df['category'].str.split('.')
df['sub_category'] = df['category'].str[1]

# %%
df.head()
# Out:
#                 order_date             order_id              user_id  \
# 0  2018-12-01 11:40:29 UTC  1924719191579950000  1842195256808830000
# 1  2018-12-01 17:38:31 UTC  1924899396621690000  1806829193678290000
# 2  2018-12-02 13:53:42 UTC  1925511016616030000  1842214461889310000
# 3  2018-12-02 17:44:02 UTC  1925626951238680000  1835566849434050000
# 4  2018-12-02 21:30:19 UTC  1925740842841010000  1873936840742920000
#
#    purchase   category_id             category  brand   price      price_id  \
# 0         1  1.806829e+18   [jewelry, earring]    0.0  561.51  1.515916e+18
# 1         1  1.806829e+18                  NaN    NaN  212.14  1.515916e+18
# 2         1  1.806829e+18   [jewelry, pendant]    1.0   54.66  1.515916e+18
# 3         1  1.806829e+18   [jewelry, pendant]    0.0   88.90  1.515916e+18
# 4         1  1.806829e+18  [jewelry, necklace]    0.0  417.67  1.515916e+18
#
#   buyer colour1 colour2      type        date  year  month sub_category
# 0   NaN     red    gold   diamond  2018-12-01  2018     12      earring
# 1   NaN  yellow    gold       NaN  2018-12-01  2018     12          NaN
# 2     f   white    gold  sapphire  2018-12-02  2018     12      pendant
# 3     f     red    gold   diamond  2018-12-02  2018     12      pendant
# 4   NaN     red    gold  amethyst  2018-12-02  2018     12     necklace

# %%
df2 = df.copy()
df2.drop(columns=['order_id','year','category','order_date'],inplace=True)

# %%
df2.head()
# Out:
#                user_id  purchase   category_id  brand   price      price_id  \
# 0  1842195256808830000         1  1.806829e+18    0.0  561.51  1.515916e+18
# 1  1806829193678290000         1  1.806829e+18    NaN  212.14  1.515916e+18
# 2  1842214461889310000         1  1.806829e+18    1.0   54.66  1.515916e+18
# 3  1835566849434050000         1  1.806829e+18    0.0   88.90  1.515916e+18
# 4  1873936840742920000         1  1.806829e+18    0.0  417.67  1.515916e+18
#
#   buyer colour1 colour2      type        date  month sub_category
# 0   NaN     red    gold   diamond  2018-12-01     12      earring
# 1   NaN  yellow    gold       NaN  2018-12-01     12          NaN
# 2     f   white    gold  sapphire  2018-12-02     12      pendant
# 3     f     red    gold   diamond  2018-12-02     12      pendant
# 4   NaN     red    gold  amethyst  2018-12-02     12     necklace

# %%
df2['user_id'].nunique()
# Out:
# 5413

# %%
df2.isnull().sum()
# Out:
# user_id             0
# purchase            0
# category_id      5352
# brand            4785
# price            5352
# price_id         5352
# buyer           48168
# colour1          7660
# colour2          5462
# type            34058
# date                0
# month               0
# sub_category    14325
# dtype: int64

# %%
# NAN remove

# %%
import seaborn as sns

df2['category_id'] = df2['category_id'].fillna(df2['category_id'].mode()[0])
df2['brand'] = df2['brand'].fillna(df2['brand'].mode()[0])
df2['price_id'] = df2['price_id'].fillna(df2['price_id'].mode()[0])
df2['buyer'] = df2['buyer'].fillna(df2['buyer'].mode()[0])
df2['colour1'] = df2['colour1'].fillna(df2['colour1'].mode()[0])
df2['colour2'] = df2['colour2'].fillna(df2['colour2'].mode()[0])
df2['type'] = df2['type'].fillna(df2['type'].mode()[0])
df2['sub_category'] = df2['sub_category'].fillna(df2['sub_category'].mode()[0])

# %%
df2.isnull().sum()
# Out:
# user_id            0
# purchase           0
# category_id        0
# brand              0
# price           5352
# price_id           0
# buyer              0
# colour1            0
# colour2            0
# type               0
# date               0
# month              0
# sub_category       0
# dtype: int64

# %%
df2.shape
# Out:
# (95911, 13)

# %%
df3 = df2.dropna(subset=['price'])

# %%
df3.size
# Out:
# 1177267

# %%
df = df3.copy()

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
df['user_id']= label_encoder.fit_transform(df['user_id'])
df['purchase']= label_encoder.fit_transform(df['purchase'])
df['category_id']= label_encoder.fit_transform(df['category_id'])
df['brand']= label_encoder.fit_transform(df['brand'])
df['price_id']= label_encoder.fit_transform(df['price_id'])
df['buyer']= label_encoder.fit_transform(df['buyer'])
df['colour1']= label_encoder.fit_transform(df['colour1'])
df['colour2']= label_encoder.fit_transform(df['colour2'])
df['type']= label_encoder.fit_transform(df['type'])
df['month']= label_encoder.fit_transform(df['month'])
df['sub_category']= label_encoder.fit_transform(df['sub_category'])

# %%
df.head()
# Out:
#    user_id  purchase  category_id  brand   price  price_id  buyer  colour1  \
# 0     2880         0           15      0  561.51      1382      0        1
# 1     2290         0           12      0  212.14       500      0        4
# 2     2881         0           16      1   54.66       438      0        3
# 3     2397         0           16      0   88.90      1381      0        1
# 4     3128         0           17      0  417.67      1080      0        1
#
#    colour2  type        date  month  sub_category
# 0        0     8  2018-12-01     11             3
# 1        0     8  2018-12-01     11             3
# 2        0    23  2018-12-02     11             5
# 3        0     8  2018-12-02     11             5
# 4        0     2  2018-12-02     11             4

# %%
def forward_selection(df, target, significance_level=0.05):
    initial_features = df.columns.tolist()
    best_features = []
    while (len(initial_features)>0):
        remaining_features = list(set(initial_features)-set(best_features))
        new_pval = pd.Series(index=remaining_features)
        for new_column in remaining_features:
            model = sm.OLS(target, sm.add_constant(df[best_features+[new_column]])).fit()
            new_pval[new_column] = model.pvalues[new_column]
        min_p_value = new_pval.min()
        if(min_p_value<significance_level):
            best_features.append(new_pval.idxmin())
        else:
            break
    return best_features

# %%
plt.figure(figsize=(24,18)) 
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
X = df.drop(['price','date'], axis=1)
y = df['price']
label_encoder = preprocessing.LabelEncoder()
y= label_encoder.fit_transform(y)

# %%
X.dtypes
# Out:
# user_id         int64
# purchase        int64
# category_id     int64
# brand           int64
# price_id        int64
# buyer           int64
# colour1         int64
# colour2         int64
# type            int64
# month           int64
# sub_category    int64
# dtype: object

# %%
y
# Out:
# array([2266, 1129,  176, ..., 2386,  351,  433])

# %%
l1 = forward_selection(X,y)
new_data = df[l1]
new_data['price'] = df['price']
new_data['date'] = df['date']

# %%
new_data.head()
# Out:
#    colour1  colour2  sub_category  category_id  type  brand  buyer  user_id  \
# 0        1        0             3           15     8      0      0     2880
# 1        4        0             3           12     8      0      0     2290
# 2        3        0             5           16    23      1      0     2881
# 3        1        0             5           16     8      0      0     2397
# 4        1        0             4           17     2      0      0     3128
#
#    month  price_id   price        date
# 0     11      1382  561.51  2018-12-01
# 1     11       500  212.14  2018-12-01
# 2     11       438   54.66  2018-12-02
# 3     11      1381   88.90  2018-12-02
# 4     11      1080  417.67  2018-12-02

# %%
new_data.shape
# Out:
# (90559, 12)

# %%
new_data.dtypes
# Out:
# colour1           int64
# colour2           int64
# sub_category      int64
# category_id       int64
# type              int64
# brand             int64
# buyer             int64
# user_id           int64
# month             int64
# price_id          int64
# price           float64
# date             object
# dtype: object

# %%
new_data = new_data[new_data['price'] < 25000]
new_data
# Out:
#        category_id  colour1  colour2  sub_category  type  brand  buyer  \
# 0               15        1        0             3     8      0      0
# 1               12        4        0             3     8      0      0
# 2               16        3        0             5    23      1      0
# 3               16        1        0             5     8      0      0
# 4               17        1        0             4     2      0      0
# ...            ...      ...      ...           ...   ...    ...    ...
# 95905           12        1        0             3     8      0      0
# 95907           12        1        0             3     8      0      0
# 95908           15        3        0             3     8      1      0
# 95909           15        3        0             3    11      0      0
# 95910           16        1        0             5     8      1      0
#
#        user_id  month  price_id   price
# 0         2880     11      1382  561.51
# 1         2290     11       500  212.14
# 2         2881     11       438   54.66
# 3         2397     11      1381   88.90
# 4         3128     11      1080  417.67
# ...        ...    ...       ...     ...
# 95905     4005     11     17353  134.29
# 95907     3861     11     17353  229.99
# 95908     4288     11     17352  630.00
# 95909     2406     11     17353   83.42
# 95910     4165     11     17303   97.12
#
# [90553 rows x 11 columns]

# %%
new_data.to_csv('/content/finaldata.csv')
